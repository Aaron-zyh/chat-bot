# %%
from tika import parser
import re

# %%
#convert .pdf files to .txt files
for i in range(10,11):
    try:
        files_adr = './data/week' + str(i)+'.pdf'
        output_adr = './data/week' + str(i)+'.txt'
        raw = tika.parser.from_file(files_adr)
        print(raw['content'])
        with open(output_adr,'w') as f:
            f.write(raw['content'])
        print('week'+ str(i)+'completed')
    except:
        pass
# Out:
# Week 10 Lectures
#
#
# 4/10/18, 3)16 pmWeek 10 Lectures
#
# Page 1 of 15file:///Users/jas/srvr/apps/cs9315/18s2/lectures/week10/notes.html
#
# Week 10 Lectures
#
# Beyond RDBMSs
#
# Future of Database 2/52
#
# Core "database" goals:
#
# deal with very large amounts of data (terabytes, petabyes, ...)
# very-high-level languages (deal with big data in uniform ways)
# query execution   (if evaluation too slow ⇒ useless)
#
# At the moment (and for the last 20 years) RDBMSs dominate ...
#
# simple/clean data model, backed up by theory
# high-level language for accessing data
# 40 years development work on RDBMS engine technology
#
# RDBMSs work well in domains with uniform, structured data.
#
# ... Future of Database 3/52
#
# Limitations/pitfalls of RDBMSs:
#
# NULL is ambiguous: unknown, not applicable, not supplied
# "limited" support for constraints/integrity and rules
# no support for uncertainty (data represents the state-of-the-world)
# ...

# %%
#reading .txt file by lines
for i in range(2):
    try:
        if i < 10:
            week = 'week0'
        else:
            week = 'week'
        file_adr = './data/'+ week + str(i)+'.txt'
        
        with open(output_adr,'r') as f:
            content = f.readlines()
    except:
        pass
print(content)
# Out:
# ['\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', 'Week 10 Lectures\n', '\n', '\n', '4/10/18, 3)16 pmWeek 10 Lectures\n', '\n', 'Page 1 of 15file:///Users/jas/srvr/apps/cs9315/18s2/lectures/week10/notes.html\n', '\n', 'Week 10 Lectures\n', '\n', 'Beyond RDBMSs\n', '\n', 'Future of Database 2/52\n', '\n', 'Core "database" goals:\n', '\n', 'deal with very large amounts of data (terabytes, petabyes, ...)\n', 'very-high-level languages (deal with big data in uniform ways)\n', 'query execution   (if evaluation too slow ⇒ useless)\n', '\n', 'At the moment (and for the last 20 years) RDBMSs dominate ...\n', '\n', 'simple/clean data model, backed up by theory\n', 'high-level language for accessing data\n', '40 years development work on RDBMS eng
# ...

# %%
#Page 1 of 15file:///Users/jas/srvr/apps/cs9315/18s2/lectures/week10/notes.html\n
content = [ele for ele in content if not bool(re.match(r"Page.*file://.*notes.html\n",ele))]
#4/10/18, 3)16 pmWeek 10 Lectures\n
content = [ele for ele in content if not bool(re.match(r".*pmWeek.*",ele))]

# %%
for i in range(len(content)):
    if bool(re.match(r".*[0-9]*/[0-9]*\n.*",content[i])):
        head_page = content[:i]
        header_stop = i
        break
header = [ele for ele in head_page if ele != '\n']
header = {'topic':'header','content':' '.join(head_page).strip('\n ')}
print(header['content'])
dataset = [header]
# Out:
# Week 10 Lectures
#
#
#
#
#  Week 10 Lectures
#
#  Beyond RDBMSs

# %%
spiliter = []
for i in range(len(content)):
    if bool(re.match(r".*[0-9]*/[0-9]*\n.*",content[i])):
        spiliter.append(i)
for i in range(len(spiliter)):
    try:
        topic = content[spiliter[i]]
        comment = ' '.join(content[spiliter[i]+1:spiliter[i+1]])
        dataset.append({'topic': topic, 'content': comment})
    except:
        dataset.append({'topic': content[spiliter[i]], \
                        'content': ' '.join(content[spiliter[i]+1:])})
        

for ele in dataset:
    print('topic: ',ele['topic'])
    print('comment:\n',ele['content'])
    print('=='*10)
# Out:
# topic:  header
# comment:
#  Week 10 Lectures
#
#
#
#
#  Week 10 Lectures
#
#  Beyond RDBMSs
# ...
# topic:  Future of Database 2/52
#
# comment:
#
#  Core "database" goals:
#
#  deal with very large amounts of data (terabytes, petabyes, ...)
#  very-high-level languages (deal with big data in uniform ways)
#  query execution   (if evaluation too slow ⇒ useless)
#
#  At the moment (and for the last 20 years) RDBMSs dominate ...
#
#  simple/clean data model, backed up by theory
#  high-level language for accessing data
#  40 years development work on RDBMS engine technology
#
#  RDBMSs work well in domains with uniform, structured data.
#
#
# ...
# topic:  ... Future of Database 3/52
#
# comment:
#
#  Limitations/pitfalls of RDBMSs:
#
#  NULL is ambiguous: unknown, not applicable, not supplied
#  "limited" support for constraints/integrity and rules
#  no support for uncertainty (data represents the state-of-the-world)
#  data model too simple (e.g. no direct support for complex objects)
# ...

# %%
bool(re.match(r".*[0-9]*/[0-9]*\n.*",'Multimedia Data 10/52\n'))
# Out:
# True
