# %%
from tika import parser
import re

#convert .pdf files to .txt files

for i in range(1,11):
    try:
        if i < 10:
            week = 'week0'
        else:
            week = 'week'
        files_adr =  './data/'+ week + str(i)+'.pdf'
        output_adr = './data/'+ week + str(i)+'.txt'
        
        raw = parser.from_file(files_adr)
        #print(raw['content'])
        with open(output_adr,'w') as f:
            f.write(raw['content'])
        print('week'+ str(i)+'completed')
    except:
        pass
# Out:
# week1completed
# week2completed
# week3completed
# week4completed
# week6completed
# week7completed
# week8completed
# week9completed
# week10completed

# %%
#reading .txt file by lines
def preprocess(content):
    #Page 1 of 15file:///Users/jas/srvr/apps/cs9315/18s2/lectures/week10/notes.html\n
    content = [ele for ele in content if not bool(re.match(r"Page.*file://.*notes.html\n",ele))]
    #4/10/18, 3)16 pmWeek 10 Lectures\n
    content = [ele for ele in content if not bool(re.match(r".*pmWeek.*",ele))]
    
    for i in range(len(content)):
        if bool(re.match(r".*[0-9]*/[0-9]*\n.*",content[i])):
            head_page = content[:i]
            header_stop = i
            break
    
    
    header = [ele for ele in head_page if ele != '\n']
    header = {'topic':'header','content':' '.join(head_page).strip('\n ')}
    print('header was finished.')
    #print(header['content'])
    dataset = [header]

    spiliter = []
    for i in range(len(content)):
        if bool(re.match(r".*[0-9]*/[0-9]*\n.*",content[i])):
            spiliter.append(i)
    print('spiliter was finished.')
    for i in range(len(spiliter)):
        try:
            topic = content[spiliter[i]]
            comment = ' '.join(content[spiliter[i]+1:spiliter[i+1]])
            dataset.append({'topic': topic, 'content': comment})
        except:
            dataset.append({'topic': content[spiliter[i]], \
                            'content': ' '.join(content[spiliter[i]+1:])})
    print('dataset was finished.')
    return dataset




for i in range(1,11):
    try:
        if i < 10:
            week = 'week0'
        else:
            week = 'week'
        file_adr = './data/'+ week + str(i)+'.txt'
        
        with open(file_adr,'r') as f:
            content = f.readlines()
        
        content = preprocess(content)
        file_adr = './data_preprocessed/'+ week + str(i)+'.txt' 
        print('content',i, 'is finished...')
        with open(file_adr, 'w') as f:
            for tp in content:
                f.write(tp['topic'])
                f.write('='*10 + '\n')
                f.write(tp['content'])
                f.write('='*11 + '\n')
        
    except:
        print('data ', i ,' was not finished.')
# Out:
# content 1 is finished...
# header was finished.
# spiliter was finished.
# dataset was finished.
# data  1  was not finished.
# content 2 is finished...
# header was finished.
# spiliter was finished.
# dataset was finished.
# data  2  was not finished.
# content 3 is finished...
# header was finished.
# spiliter was finished.
# dataset was finished.
# data  3  was not finished.
# content 4 is finished...
# header was finished.
# spiliter was finished.
# dataset was finished.
# data  4  was not finished.
# data  5  was not finished.
# content 6 is finished...
# header was finished.
# spiliter was finished.
# dataset was finished.
# data  6  was not finished.
# content 7 is finished...
# header was finished.
# spiliter was finished.
# dataset was finished.
# data  7  was not finished.
# content 8 is finished...
# header was finished.
# spiliter was finished.
# dataset was finished.
# data  8  was not finished.
# content 9 is finished...
# header was finished.
# spiliter was finished.
# dataset was finished.
# data  9  was not finished.
# content 10 is finished...
# header was finished.
# spiliter was finished.
# dataset was finished.
# data  10  was not finished.

# %%
# !rm ./data/*.txt
